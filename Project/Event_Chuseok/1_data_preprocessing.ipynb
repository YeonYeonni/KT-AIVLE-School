# %%
import pandas as pd
import requests, json

# 경고
import warnings
warnings.filterwarnings(action='ignore')
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## 1. 소요시간

# %% [markdown]
# #### 1) 2021년 9월 20일

# %%
key = 9085291297
iYear = 2021
iStUnitCode = 101
iEdUnitCode = 140
numOfRows = 1000
pageNo = 4
url = f'http://data.ex.co.kr/openapi/specialAnal/intercityLeadTime?key={key}&type=json&iYear={iYear}&iStUnitCode={iStUnitCode}&iEdUnitCode={iEdUnitCode}&numOfRows={numOfRows}&pageNo={pageNo}'

# %%
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['intercityLeadTimeLists'])
df_21 = pd.DataFrame(lst)[['stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'stdHour', 'edUnitNm', 'trtm']]

# %%
df_21 = df_21.loc[df_21['sphlDfttScopTypeNm'] == 'D-1']
df_21 = df_21.reset_index()
df_21.head(2)
# Out:
#    index stdYear sphlDfttNm sphlDfttScopTypeNm stdHour edUnitNm  \
# 0      3    2021         추석                D-1      00       부산
# 1      4    2021         추석                D-1      01       부산
#
#                            trtm
# 0  228.716000000000000000000000
# 1  240.875000000000000000000000

# %% [markdown]
# #### 2) 2020년 9월 30일

# %%
key = 9085291297
iYear = 2020
iStUnitCode = 101
iEdUnitCode = 140
numOfRows = 1000
pageNo = 4
url = f'http://data.ex.co.kr/openapi/specialAnal/intercityLeadTime?key={key}&type=json&iYear={iYear}&iStUnitCode={iStUnitCode}&iEdUnitCode={iEdUnitCode}&numOfRows={numOfRows}&pageNo={pageNo}'

# %%
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['intercityLeadTimeLists'])
df_20 = pd.DataFrame(lst)[['stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'stdHour', 'edUnitNm', 'trtm']]

# %%
df_20 = df_20.loc[df_20['sphlDfttScopTypeNm'] == 'D-1']
df_20 = df_20.reset_index()
df_20.head(2)
# Out:
#    index stdYear sphlDfttNm sphlDfttScopTypeNm stdHour edUnitNm  \
# 0      3    2020         추석                D-1      00       부산
# 1      4    2020         추석                D-1      01       부산
#
#                            trtm
# 0  285.866500000000000000000000
# 1  281.199500000000000000000000

# %% [markdown]
# #### 3) 2019년 9월 12일

# %%
key = 9085291297
iYear = 2019
iStUnitCode = 101
iEdUnitCode = 140
numOfRows = 1000
pageNo = 4
url = f'http://data.ex.co.kr/openapi/specialAnal/intercityLeadTime?key={key}&type=json&iYear={iYear}&iStUnitCode={iStUnitCode}&iEdUnitCode={iEdUnitCode}&numOfRows={numOfRows}&pageNo={pageNo}'

# %%
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['intercityLeadTimeLists'])
df_19 = pd.DataFrame(lst)[['stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'stdHour', 'edUnitNm', 'trtm']]

# %%
df_19 = df_19.loc[df_19['sphlDfttScopTypeNm'] == 'D-1']
df_19 = df_19.reset_index()
df_19.head(2)
# Out:
#    index stdYear sphlDfttNm sphlDfttScopTypeNm stdHour edUnitNm  \
# 0      8    2019         추석                D-1      00       부산
# 1      9    2019         추석                D-1      01       부산
#
#                            trtm
# 0  369.238666666666666666666666
# 1  368.961000000000000000000000

# %% [markdown]
# #### 4) 2018년 9월 23일

# %%
key = 9085291297
iYear = 2018
iStUnitCode = 101
iEdUnitCode = 140
numOfRows = 1000
pageNo = 4
url = f'http://data.ex.co.kr/openapi/specialAnal/intercityLeadTime?key={key}&type=json&iYear={iYear}&iStUnitCode={iStUnitCode}&iEdUnitCode={iEdUnitCode}&numOfRows={numOfRows}&pageNo={pageNo}'

# %%
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['intercityLeadTimeLists'])
df_18 = pd.DataFrame(lst)[['stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'stdHour', 'edUnitNm', 'trtm']]

# %%
df_18 = df_18.loc[df_18['sphlDfttScopTypeNm'] == 'D-1']
df_18 = df_18.reset_index()
df_18.head(2)
# Out:
#    index stdYear sphlDfttNm sphlDfttScopTypeNm stdHour edUnitNm  \
# 0     12    2018         추석                D-1      00       부산
# 1     13    2018         추석                D-1      01       부산
#
#                            trtm
# 0  374.616333333333333333333333
# 1  365.427333333333333333333333

# %% [markdown]
# #### 5) 2017년 10월 3일

# %%
key = 9085291297
iYear = 2017
iStUnitCode = 101
iEdUnitCode = 140
numOfRows = 1000
pageNo = 1
url = f'http://data.ex.co.kr/openapi/specialAnal/intercityLeadTime?key={key}&type=json&iYear={iYear}&iStUnitCode={iStUnitCode}&iEdUnitCode={iEdUnitCode}&numOfRows={numOfRows}&pageNo={pageNo}'

# %%
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()

# %%
lst = list(data['intercityLeadTimeLists'])
df_17 = pd.DataFrame(lst)[['stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'stdHour', 'edUnitNm', 'trtm']]

# %%
df_17 = df_17.loc[df_17['sphlDfttScopTypeNm'] == 'D-1']
df_17 = df_17.reset_index()
df_17.head(2)
# Out:
#    index stdYear sphlDfttNm sphlDfttScopTypeNm stdHour edUnitNm  \
# 0     48    2017         추석                D-1      00       부산
# 1     49    2017         추석                D-1      01       부산
#
#                            trtm
# 0  355.149750000000000000000000
# 1  338.237250000000000000000000

# %% [markdown]
# #### 6) concat

# %%
time = pd.concat([df_17, df_18, df_19, df_20, df_21], axis=0)

# %%
time = time.drop(columns = ['index', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'edUnitNm'])

# %%
# target float으로 변환
time['trtm'] = time['trtm'].astype('float')

# %%
time
# Out:
#    stdYear stdHour        trtm
# 0     2017      00  355.149750
# 1     2017      01  338.237250
# 2     2017      02  332.094333
# 3     2017      03  321.937250
# 4     2017      04  319.120250
# 5     2017      05  312.791500
# 6     2017      06  353.299667
# 7     2017      07  365.478750
# 8     2017      08  359.405333
# 9     2017      09  371.227333
# 10    2017      10  409.037000
# 11    2017      11  431.694000
# 12    2017      12  430.466667
# 13    2017      13  424.988667
# 14    2017      14  419.583000
# 15    2017      15  419.872000
# 16    2017      16  424.760667
# 17    2017      17  413.699500
# 18    2017      18  399.408000
# 19    2017      19  425.510667
# 20    2017      20  459.525000
# 21    2017      21  424.825000
# 22    2017      22  362.250000
# 23    2017      23  353.050000
# 0     2018      00  374.616333
# 1     2018      01  365.427333
# 2     2018      02  350.572000
# 3     2018      03  333.588333
# 4     2018      04  316.266333
# ...

# %% [markdown]
# ## 2. 기상

# %% [markdown]
# #### 1) 2021년 9월 20일

# %%
# seoul
seoul_21 = pd.read_csv('seoul_21.csv', sep=',', encoding='cp949')
# busan
busan_21 = pd.read_csv('busan_21.csv', sep=',', encoding='cp949')
# 경북
kb_21 = pd.read_csv('kyeongbook_21.csv', sep=',', encoding='cp949')
# 충남
cn_21 = pd.read_csv('choongnam_21.csv', sep=',', encoding='cp949')
# 충북
cb_21 = pd.read_csv('choongbook_21.csv', sep=',', encoding='cp949')

columns = ['지점', '기온 QC플래그', '강수량 QC플래그', '풍속 QC플래그',
           '풍향 QC플래그', '현지기압 QC플래그', '해면기압 QC플래그',
           '일조 QC플래그', '일사 QC플래그', '지면온도 QC플래그', '습도 QC플래그',
           '운형(운형약어)', '지면상태(지면상태코드)', '현상번호(국내식)']

seoul_21 = seoul_21.drop(columns = columns)
busan_21 = busan_21.drop(columns = columns)
kb_21 = kb_21.drop(columns = columns)
cn_21 = cn_21.drop(columns = columns)
cb_21 = cb_21.drop(columns = columns)

# %%
cn21_1 = cn_21.loc[cn_21['지점명']=='천안']
cb21_1 = cb_21.loc[cb_21['지점명']=='청주']
cb21_2 = cb_21.loc[cb_21['지점명']=='추풍령']
kb21_1 = kb_21.loc[kb_21['지점명']=='영천']
kb21_2 = kb_21.loc[kb_21['지점명']=='경주시']

# %% [markdown]
# #### 2) 2020년 9월 30일

# %%
# seoul
seoul_20 = pd.read_csv('seoul_20.csv', sep=',', encoding='cp949')
# busan
busan_20 = pd.read_csv('busan_20.csv', sep=',', encoding='cp949')
# 경북
kb_20 = pd.read_csv('kyeongbook_20.csv', sep=',', encoding='cp949')
# 충남
cn_20 = pd.read_csv('choongnam_20.csv', sep=',', encoding='cp949')
# 충북
cb_20 = pd.read_csv('choongbook_20.csv', sep=',', encoding='cp949')

seoul_20 = seoul_20.drop(columns = columns)
busan_20 = busan_20.drop(columns = columns)
kb_20 = kb_20.drop(columns = columns)
cn_20 = cn_20.drop(columns = columns)
cb_20 = cb_20.drop(columns = columns)

# %%
cn20_1 = cn_20.loc[cn_20['지점명']=='천안']
cb20_1 = cb_20.loc[cb_20['지점명']=='청주']
cb20_2 = cb_20.loc[cb_20['지점명']=='추풍령']
kb20_1 = kb_20.loc[kb_20['지점명']=='영천']
kb20_2 = kb_20.loc[kb_20['지점명']=='경주시']

# %% [markdown]
# #### 3) 2019년 9월 12일

# %%
# seoul
seoul_19 = pd.read_csv('seoul_19.csv', sep=',', encoding='cp949')
# busan
busan_19 = pd.read_csv('busan_19.csv', sep=',', encoding='cp949')
# 경북
kb_19 = pd.read_csv('kyeongbook_19.csv', sep=',', encoding='cp949')
# 충남
cn_19 = pd.read_csv('choongnam_19.csv', sep=',', encoding='cp949')
# 충북
cb_19 = pd.read_csv('choongbook_19.csv', sep=',', encoding='cp949')

seoul_19 = seoul_19.drop(columns = columns)
busan_19 = busan_19.drop(columns = columns)
kb_19 = kb_19.drop(columns = columns)
cn_19 = cn_19.drop(columns = columns)
cb_19 = cb_19.drop(columns = columns)

# %%
cn19_1 = cn_19.loc[cn_19['지점명']=='천안']
cb19_1 = cb_19.loc[cb_19['지점명']=='청주']
cb19_2 = cb_19.loc[cb_19['지점명']=='추풍령']
kb19_1 = kb_19.loc[kb_19['지점명']=='영천']
kb19_2 = kb_19.loc[kb_19['지점명']=='경주시']

# %% [markdown]
# #### 4) 2018년 9월 23일

# %%
# seoul
seoul_18 = pd.read_csv('seoul_18.csv', sep=',', encoding='cp949')
# busan
busan_18 = pd.read_csv('busan_18.csv', sep=',', encoding='cp949')
# 경북
kb_18 = pd.read_csv('kyeongbook_18.csv', sep=',', encoding='cp949')
# 충남
cn_18 = pd.read_csv('choongnam_18.csv', sep=',', encoding='cp949')
# 충북
cb_18 = pd.read_csv('choongbook_18.csv', sep=',', encoding='cp949')

seoul_18 = seoul_18.drop(columns = columns)
busan_18 = busan_18.drop(columns = columns)
kb_18 = kb_18.drop(columns = columns)
cn_18 = cn_18.drop(columns = columns)
cb_18 = cb_18.drop(columns = columns)

# %%
cn18_1 = cn_18.loc[cn_18['지점명']=='천안']
cb18_1 = cb_18.loc[cb_18['지점명']=='청주']
cb18_2 = cb_18.loc[cb_18['지점명']=='추풍령']
kb18_1 = kb_18.loc[kb_18['지점명']=='영천']
kb18_2 = kb_18.loc[kb_18['지점명']=='경주시']

# %% [markdown]
# #### 5) 2017년 10월 3일

# %%
# seoul
seoul_17 = pd.read_csv('seoul_17.csv', sep=',', encoding='cp949')
# busan
busan_17 = pd.read_csv('busan_17.csv', sep=',', encoding='cp949')
# 경북
kb_17 = pd.read_csv('kyeongbook_17.csv', sep=',', encoding='cp949')
# 충남
cn_17 = pd.read_csv('choongnam_17.csv', sep=',', encoding='cp949')
# 충북
cb_17 = pd.read_csv('choongbook_17.csv', sep=',', encoding='cp949')

seoul_17 = seoul_17.drop(columns = columns)
busan_17 = busan_17.drop(columns = columns)
kb_17 = kb_17.drop(columns = columns)
cn_17 = cn_17.drop(columns = columns)
cb_17 = cb_17.drop(columns = columns)

# %%
cn17_1 = cn_17.loc[cn_17['지점명']=='천안']
cb17_1 = cb_17.loc[cb_17['지점명']=='청주']
cb17_2 = cb_17.loc[cb_17['지점명']=='추풍령']
kb17_1 = kb_17.loc[kb_17['지점명']=='영천']
kb17_2 = kb_17.loc[kb_17['지점명']=='경주시']

# %% [markdown]
# #### 6) concat

# %%
# 서울
seoul = pd.concat([seoul_17, seoul_18, seoul_19, seoul_20, seoul_21], axis=0)
seoul = seoul.reset_index()

# 천안
cheon = pd.concat([cn17_1, cn18_1, cn19_1, cn20_1, cn21_1], axis=0)
cheon = cheon.reset_index()

# 청주
cheong = pd.concat([cb17_1, cb18_1, cb19_1, cb20_1, cb21_1], axis=0)
cheong = cheong.reset_index()

# 추풍령
choo = pd.concat([cb17_2, cb18_2, cb19_2, cb20_2, cb21_2], axis=0)
choo = choo.reset_index()

# 영천
young = pd.concat([kb17_1, kb18_1, kb19_1, kb20_1, kb21_1], axis=0)
young = young.reset_index()

# 경주시
gyoung = pd.concat([kb17_2, kb18_2, kb19_2, kb20_2, kb21_2], axis=0)
gyoung = gyoung.reset_index()

# %%
place = pd.concat([seoul, cheon, cheong, choo, young, gyoung], axis=1)
place = place.drop(columns = ['index'])

# %% [markdown]
# ## 3. 교통량

# %% [markdown]
# #### 1) 2021년 9월 20일

# %%
key = 9085291297
iStdYear = 2021
url = f'http://data.ex.co.kr/openapi/specialAnal/trafficFlowByTime?key=9085291297&type=json&iStdYear={iStdYear}'
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['trafficFlowByTimeLists'])

# %%
traf_21 = pd.DataFrame(lst)[['stdHour', 'stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'trfl']]
traf_21 = traf_21.loc[traf_21['sphlDfttScopTypeNm'] == 'D-1']
traf_21 = traf_21.loc[traf_21['sphlDfttNm'] == '추석']
traf_21 = traf_21.sort_values('stdHour')
traf_21 = traf_21.reset_index()
traf_21 = traf_21.drop(columns='index')

# %% [markdown]
# #### 2) 2020년 9월 30일

# %%
key = 9085291297
iStdYear = 2020
url = f'http://data.ex.co.kr/openapi/specialAnal/trafficFlowByTime?key=9085291297&type=json&iStdYear={iStdYear}'
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['trafficFlowByTimeLists'])

# %%
traf_20 = pd.DataFrame(lst)[['stdHour', 'stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'trfl']]
traf_20 = traf_20.loc[traf_20['sphlDfttScopTypeNm'] == 'D-1']
traf_20 = traf_20.loc[traf_20['sphlDfttNm'] == '추석']
traf_20traf_20 = traf_20.sort_values('stdHour')
traf_20 = traf_20.reset_index()
traf_20 = traf_20.drop(columns='index')

# %% [markdown]
# #### 3) 2019년 9월 12일

# %%
key = 9085291297
iStdYear = 2019
url = f'http://data.ex.co.kr/openapi/specialAnal/trafficFlowByTime?key=9085291297&type=json&iStdYear={iStdYear}'
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['trafficFlowByTimeLists'])

# %%
traf_19 = pd.DataFrame(lst)[['stdHour', 'stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'trfl']]
traf_19 = traf_19.loc[traf_19['sphlDfttScopTypeNm'] == 'D-1']
traf_19 = traf_19.loc[traf_19['sphlDfttNm'] == '추석']
traf_19 = traf_19.sort_values('stdHour')
traf_19 = traf_19.reset_index()
traf_19 = traf_19.drop(columns='index')

# %% [markdown]
# #### 4) 2018년 9월 23일

# %%
key = 9085291297
iStdYear = 2018
url = f'http://data.ex.co.kr/openapi/specialAnal/trafficFlowByTime?key=9085291297&type=json&iStdYear={iStdYear}'
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['trafficFlowByTimeLists'])

# %%
traf_18 = pd.DataFrame(lst)[['stdHour', 'stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'trfl']]
traf_18 = traf_18.loc[traf_18['sphlDfttScopTypeNm'] == 'D-1']
traf_18 = traf_18.loc[traf_18['sphlDfttNm'] == '추석']
traf_18 = traf_18.sort_values('stdHour')
traf_18 = traf_18.reset_index()
traf_18 = traf_18.drop(columns='index')

# %% [markdown]
# ####  5) 2017년 10월 3일

# %%
key = 9085291297
iStdYear = 2017
url = f'http://data.ex.co.kr/openapi/specialAnal/trafficFlowByTime?key=9085291297&type=json&iStdYear={iStdYear}'
response = requests.get(url) # get 방식.
data = response.json() # 문자열을 리스트로 바꿔주는 .json()
lst = list(data['trafficFlowByTimeLists'])

# %%
traf_17 = pd.DataFrame(lst)[['stdHour', 'stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm', 'trfl']]
traf_17 = traf_17.loc[traf_17['sphlDfttScopTypeNm'] == 'D-1']
traf_17 = traf_17.loc[traf_17['sphlDfttNm'] == '추석']
traf_17 = traf_17.sort_values('stdHour')
traf_17 = traf_17.reset_index()
traf_17 = traf_17.drop(columns='index')

# %% [markdown]
# #### 6) concat

# %%
traffic = pd.concat([traf_17, traf_18, traf_19, traf_20, traf_21], axis=0)

# %%
traffic = traffic.drop(columns=['stdHour', 'stdYear', 'sphlDfttNm', 'sphlDfttScopTypeNm'])

# %% [markdown]
# ## 4. All Concat

# %%
time = time.reset_index()
place = place.reset_index()
traffic = traffic.reset_index()

# %%
df = pd.concat([time, place, traffic], axis=1)

# %%
df.head()
# Out:
#    index stdYear stdHour        trtm  index 지점명                일시  기온(°C)  \
# 0      0    2017      00  355.149750      0  서울  2017-10-03 00:00    19.0
# 1      1    2017      01  338.237250      1  서울  2017-10-03 01:00    17.7
# 2      2    2017      02  332.094333      2  서울  2017-10-03 02:00    16.6
# 3      3    2017      03  321.937250      3  서울  2017-10-03 03:00    15.7
# 4      4    2017      04  319.120250      4  서울  2017-10-03 04:00    15.2
#
#    강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  이슬점온도(°C)  현지기압(hPa)  \
# 0      NaN      3.5       290     60      13.1       11.0     1003.7
# 1      NaN      2.6       320     60      12.1        9.8     1004.4
# 2      NaN      1.4       290     59      11.1        8.5     1005.2
# 3      NaN      2.0       290     61      10.8        8.1     1005.0
# 4      NaN      2.1       270     64      11.0        8.4     1005.3
#
#    해면기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  3시간신적설(cm)  전운량(10분위)  중하층운량(10분위)  \
# ...

# %% [markdown]
# ## 5. 전처리

# %%
df['강수량(mm)'] = df['강수량(mm)'].fillna(0)
df['적설(cm)'] = df['적설(cm)'].fillna(0)
df['3시간신적설(cm)'] = df['3시간신적설(cm)'].fillna(0)

# %%
df = df.drop(columns = ['index', '지점명', '일시', '5cm 지중온도(°C)', '10cm 지중온도(°C)', 
                        '20cm 지중온도(°C)', '30cm 지중온도(°C)', '일조(hr)', '일사(MJ/m2)',
                        'stdYear', 'stdHour'])

# %%
# interpolate
df.interpolate(method = 'linear', inplace = True)

# %%
# 나머지는 0으로 채워보자
df = df.fillna(0)

# %%
df.to_csv('df.csv')

# %%
df.head()
# Out:
#          trtm  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  이슬점온도(°C)  \
# 0  355.149750    19.0      0.0      3.5       290     60      13.1       11.0
# 1  338.237250    17.7      0.0      2.6       320     60      12.1        9.8
# 2  332.094333    16.6      0.0      1.4       290     59      11.1        8.5
# 3  321.937250    15.7      0.0      2.0       290     61      10.8        8.1
# 4  319.120250    15.2      0.0      2.1       270     64      11.0        8.4
#
#    현지기압(hPa)  해면기압(hPa)  적설(cm)  3시간신적설(cm)  전운량(10분위)  중하층운량(10분위)  \
# 0     1003.7     1013.7     0.0         0.0        0.0            0
# 1     1004.4     1014.4     0.0         0.0        0.0            0
# 2     1005.2     1015.3     0.0         0.0        0.0            0
# 3     1005.0     1015.2     0.0         0.0        0.0            0
# 4     1005.3     1015.5     0.0         0.0        1.0            0
#
#    최저운고(100m )  시정(10m)  지면온도(°C)  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 98 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   trtm         120 non-null    float64
#  1   기온(°C)       120 non-null    float64
#  2   강수량(mm)      120 non-null    float64
#  3   풍속(m/s)      120 non-null    float64
#  4   풍향(16방위)     120 non-null    int64
#  5   습도(%)        120 non-null    int64
#  6   증기압(hPa)     120 non-null    float64
#  7   이슬점온도(°C)    120 non-null    float64
#  8   현지기압(hPa)    120 non-null    float64
#  9   해면기압(hPa)    120 non-null    float64
#  10  적설(cm)       120 non-null    float64
#  11  3시간신적설(cm)   120 non-null    float64
#  12  전운량(10분위)    120 non-null    float64
#  13  중하층운량(10분위)  120 non-null    int64
#  14  최저운고(100m )  120 non-null    float64
#  15  시정(10m)      120 non-null    int64
#  16  지면온도(°C)     120 non-null    float64
#  17  기온(°C)       120 non-null    float64
# ...
